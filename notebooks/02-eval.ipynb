# %% [markdown]
# # Phase 5 evaluation
#
# Run an explicitly pinned checkpoint through the same harness used for local and HTTP policies.

# %%
# !smolqwen evaluate --checkpoint /path/to/merged-checkpoint --revision <commit-sha> --tag sft
