# %% [markdown]
# # Agentic GRPO
#
# Thin Colab wrapper around the checked-in CLI. Run from the repository root after the merged SFT checkpoint and target-profile rollout A/B evidence exist.

# %%
# !smolqwen profile-difficulty --profile l4

# %%
# !smolqwen train-grpo --profile l4

# %% [markdown]
# If the VM was reclaimed, resume the same optimizer, curriculum, and W&B run:

# %%
# !smolqwen train-grpo --profile l4 --resume
