# %% [markdown]
# # Serve smolqwen
#
# The launcher starts the authenticated proxy before creating the public tunnel. It prints the key file path, never the key.

# %%
# !bash scripts/run_colab_serve.sh
