# %% [markdown]
# # GPU capability probe
#
# Run this notebook once in an L4 session and once in an A100 session. The setup script verifies the locked torch ABI before building kernel packages.

# %%
# !bash scripts/setup_colab.sh
# !uv run smolqwen probe
